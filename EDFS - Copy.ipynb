# %%
import sqlite3
from sqlite3 import Error
import os
import pandas as pd
import numpy as np
import re

# %%
root_path = './'

# %%
root_path = './'
files = []
for root, _, file in os.walk(root_path):
    for f in file:
        if (os.path.splitext(f)[1] == ".csv"):
            file_path = os.path.join(root, f)
            activity = os.path.split(root)[-1]
            files.append(file_path)

# %%
files
# Out:
# ['./Life Expectancy (WHO)\\Life Expectancy Data.csv',
#  './Mental Health and Suicide Rates\\Age-standardized suicide rates.csv',
#  './Mental Health and Suicide Rates\\Crude suicide rates.csv',
#  './Mental Health and Suicide Rates\\Facilities.csv',
#  './Mental Health and Suicide Rates\\Human Resources.csv',
#  './Mental Health Dataset\\mental-and-substance-use-as-share-of-disease.csv',
#  './Mental Health Dataset\\prevalence-by-mental-and-substance-use-disorder.csv',
#  './Mental Health Dataset\\prevalence-of-depression-males-vs-females.csv',
#  './Mental Health Dataset\\share-with-depression.csv',
#  './Mental Health Dataset\\share-with-mental-and-substance-disorders.csv',
#  './Mental Health Dataset\\share-with-mental-or-substance-disorders-by-sex.csv',
#  './Mental Health in Tech Survey\\survey.csv',
#  './World Happiness Report 2015-2021\\2015.csv',
#  './World Happiness Report 2015-2021\\2016.csv',
#  './World Happiness Report 2015-2021\\2017.csv',
#  './World Happiness Report 2015-2021\\2018.csv',
#  './World Happiness Report 2015-2021\\2019.csv',
#  './World Happiness Report 2015-2021\\2020.csv',
#  './World Happiness Report 2015-2021\\2021.csv']

# %%
for i in files:
    a = i.split('\\')
    len(a)
    print(a[-2])
# Out:
# ./Life Expectancy (WHO)
# ./Mental Health and Suicide Rates
# ./Mental Health and Suicide Rates
# ./Mental Health and Suicide Rates
# ./Mental Health and Suicide Rates
# ./Mental Health Dataset
# ./Mental Health Dataset
# ./Mental Health Dataset
# ./Mental Health Dataset
# ./Mental Health Dataset
# ./Mental Health Dataset
# ./Mental Health in Tech Survey
# ./World Happiness Report 2015-2021
# ./World Happiness Report 2015-2021
# ./World Happiness Report 2015-2021
# ./World Happiness Report 2015-2021
# ./World Happiness Report 2015-2021
# ./World Happiness Report 2015-2021
# ./World Happiness Report 2015-2021

# %%
for root, _, file in os.walk(root_path):
    for f in file:
        if (os.path.splitext(f)[1] == ".csv"):
            print(f)
# Out:
# Life Expectancy Data.csv
# Age-standardized suicide rates.csv
# Crude suicide rates.csv
# Facilities.csv
# Human Resources.csv
# mental-and-substance-use-as-share-of-disease.csv
# prevalence-by-mental-and-substance-use-disorder.csv
# prevalence-of-depression-males-vs-females.csv
# share-with-depression.csv
# share-with-mental-and-substance-disorders.csv
# share-with-mental-or-substance-disorders-by-sex.csv
# survey.csv
# 2015.csv
# 2016.csv
# 2017.csv
# 2018.csv
# 2019.csv
# 2020.csv
# 2021.csv

# %%
files
# Out:
# ['./Life Expectancy (WHO)\\Life Expectancy Data.csv',
#  './Mental Health and Suicide Rates\\Age-standardized suicide rates.csv',
#  './Mental Health and Suicide Rates\\Crude suicide rates.csv',
#  './Mental Health and Suicide Rates\\Facilities.csv',
#  './Mental Health and Suicide Rates\\Human Resources.csv',
#  './Mental Health Dataset\\mental-and-substance-use-as-share-of-disease.csv',
#  './Mental Health Dataset\\prevalence-by-mental-and-substance-use-disorder.csv',
#  './Mental Health Dataset\\prevalence-of-depression-males-vs-females.csv',
#  './Mental Health Dataset\\share-with-depression.csv',
#  './Mental Health Dataset\\share-with-mental-and-substance-disorders.csv',
#  './Mental Health Dataset\\share-with-mental-or-substance-disorders-by-sex.csv',
#  './Mental Health in Tech Survey\\survey.csv',
#  './World Happiness Report 2015-2021\\2015.csv',
#  './World Happiness Report 2015-2021\\2016.csv',
#  './World Happiness Report 2015-2021\\2017.csv',
#  './World Happiness Report 2015-2021\\2018.csv',
#  './World Happiness Report 2015-2021\\2019.csv',
#  './World Happiness Report 2015-2021\\2020.csv',
#  './World Happiness Report 2015-2021\\2021.csv']

# %%
for i in files:
    data_test = pd.read_csv(i)

# %%
Life_Expectancy_Data = pd.read_csv(files[0])
Mental_Health_Suicide_Rates_Age_standardized_suicide_rates = pd.read_csv(files[1])
Mental_Health_Suicide_Rates_Crude_suicide_rates = pd.read_csv(files[2])
Mental_Health_Suicide_Rates_Facilities = pd.read_csv(files[3])
Mental_Health_Suicide_Rates_Human_Resources = pd.read_csv(files[4])
Mental_Health_Dataset_mental_and_substance_use_as_share_of_disease = pd.read_csv(files[5])
Mental_Health_Dataset_prevalence_by_mental_and_substance_use_disorder = pd.read_csv(files[6])
Mental_Health_Dataset_prevalence_of_depression_males_vs_females = pd.read_csv(files[7])
Mental_Health_Dataset_share_with_depression = pd.read_csv(files[8])
Mental_Health_Dataset_share_with_mental_and_substance_disorders = pd.read_csv(files[9])
Mental_Health_Dataset_share_with_mental_or_substance_disorders_by_sex = pd.read_csv(files[10])
Mental_Health_Tech_Survey_survey = pd.read_csv(files[11])
World_Happiness_Report_2015_2021_2015 = pd.read_csv(files[12])
World_Happiness_Report_2015_2021_2016 = pd.read_csv(files[13])
World_Happiness_Report_2015_2021_2017 = pd.read_csv(files[14])
World_Happiness_Report_2015_2021_2018 = pd.read_csv(files[15])
World_Happiness_Report_2015_2021_2019 = pd.read_csv(files[16])
World_Happiness_Report_2015_2021_2020 = pd.read_csv(files[17])
World_Happiness_Report_2015_2021_2021 = pd.read_csv(files[18])

# %%
World_Happiness_Report_2015_2021_2021
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# 4                             0.027         7.518         7.410
# ..                              ...           ...           ...
# 144                           0.120         3.748         3.276
# 145                           0.074         3.611         3.322
# 146                           0.068         3.548         3.282
# 147                           0.058         3.259         3.030
# 148                           0.038         2.596         2.449
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                   10.775           0.954                   72.000
# 1                   10.933           0.954                   72.700
# 2                   11.117           0.942                   74.400
# 3                   10.878           0.983                   73.000
# 4                   10.932           0.942                   72.400
# ..                     ...             ...                      ...
# 144                  7.926           0.787                   48.700
# 145                  9.782           0.784                   59.269
# 146                  7.676           0.552                   61.400
# 147                  7.943           0.750                   56.201
# 148                  7.695           0.463                   52.493
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                           0.949      -0.098                      0.186
# 1                           0.946       0.030                      0.179
# 2                           0.919       0.025                      0.292
# 3                           0.955       0.160                      0.673
# 4                           0.913       0.175                      0.338
# ..                            ...         ...                        ...
# 144                         0.715      -0.131                      0.915
# 145                         0.824      -0.246                      0.801
# 146                         0.897       0.061                      0.167
# 147                         0.677      -0.047                      0.821
# 148                         0.382      -0.102                      0.924
#
#      Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                        2.43                             1.446
# 1                        2.43                             1.502
# 2                        2.43                             1.566
# 3                        2.43                             1.482
# 4                        2.43                             1.501
# ..                        ...                               ...
# 144                      2.43                             0.451
# 145                      2.43                             1.099
# 146                      2.43                             0.364
# 147                      2.43                             0.457
# 148                      2.43                             0.370
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                           1.106                                  0.741
# 1                           1.108                                  0.763
# 2                           1.079                                  0.816
# 3                           1.172                                  0.772
# 4                           1.079                                  0.753
# ..                            ...                                    ...
# 144                         0.731                                  0.007
# 145                         0.724                                  0.340
# 146                         0.202                                  0.407
# 147                         0.649                                  0.243
# 148                         0.000                                  0.126
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                         0.691                     0.124
# 1                                         0.686                     0.208
# 2                                         0.653                     0.204
# 3                                         0.698                     0.293
# 4                                         0.647                     0.302
# ..                                          ...                       ...
# 144                                       0.405                     0.103
# 145                                       0.539                     0.027
# 146                                       0.627                     0.227
# 147                                       0.359                     0.157
# 148                                       0.000                     0.122
#
#      Explained by: Perceptions of corruption  Dystopia + residual
# 0                                      0.481                3.253
# 1                                      0.485                2.868
# 2                                      0.413                2.839
# 3                                      0.170                2.967
# 4                                      0.384                2.798
# ..                                       ...                  ...
# 144                                    0.015                1.800
# 145                                    0.088                0.648
# 146                                    0.493                1.095
# 147                                    0.075                1.205
# 148                                    0.010                1.895
#
# [149 rows x 20 columns]

# %%
# def create_connection(db_file):
#     """ create a database connection to a SQLite database """
#     conn = None
#     try:
#         conn = sqlite3.connect(db_file)
#         print(sqlite3.version)
#     except Error as e:
#         print(e)
#     finally:
#         if conn:
#             conn.close()


# if __name__ == '__main__':
#     create_connection(r"./pythonsqlite.db")

# %%
# cur = conn.cursor()
# cur.execute('''SELECT * FROM Life_Expectancy_Data''').fetchall()

# %%
# pd.read_sql('''SELECT * FROM Life_Expectancy_Data''', conn)

# %%
# pd.read_sql('''SELECT * FROM Life_Expectancy_Data PARTITION BY HASH(Country) PARTITIONS 4''', conn)

# %%
# len(Life_Expectancy_Data)//3

# %%
# Life_Expectancy_Data[:len(Life_Expectancy_Data)//3]

# %%
# Life_Expectancy_Data[len(Life_Expectancy_Data)//3:len(Life_Expectancy_Data)//3*2]

# %%
# Life_Expectancy_Data[len(Life_Expectancy_Data)//3*2:len(Life_Expectancy_Data)]

# %%
def create_connection(db_file):
    """ create a database connection to a SQLite database """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
    finally:
        if conn:
            conn.close()


if __name__ == '__main__':
    create_connection(r"./test1.db")
# Out:
# 2.6.0

# %%
# conn = sqlite3.connect('./test1.db')
# cur = conn.cursor()
# Life_Expectancy_Data.to_sql('Life_Expectancy_Data', conn, if_exists='append', index = False)
# conn.commit()
# cur.close()

# %%
conn = sqlite3.connect('./test1.db')
cur = conn.cursor()
for i in files:
    casedf = pd.read_csv(i)
    #equal length partition
    casedf_p1 = casedf[:len(casedf)//3]
    casedf_p2 = casedf[len(casedf)//3:len(casedf)//3*2]
    casedf_p3 = casedf[len(casedf)//3*2:len(casedf)]
    
    file_name = i.split('\\')[-1]
    file_name = file_name.split('.')[0]
    file_name_p1 = file_name + '_p1'
    file_name_p2 = file_name + '_p2'
    file_name_p3 = file_name + '_p3'
    
#     casedf_p1.to_csv(file_name_p1 + '.csv')
#     casedf_p2.to_csv(file_name_p2 + '.csv')
#     casedf_p3.to_csv(file_name_p3 + '.csv')
    
    casedf_p1.to_sql(file_name_p1, conn, if_exists='append', index = False)
    cur.close()
    casedf_p2.to_sql(file_name_p2, conn, if_exists='append', index = False)
    cur.close()
    casedf_p3.to_sql(file_name_p3, conn, if_exists='append', index = False)
    cur.close()

# %%
pd.read_sql('''SELECT * FROM survey_p2''', conn)
# Out:
#                Timestamp  Age  Gender         Country state self_employed  \
# 0    2014-08-27 15:31:40   55       M   United States    ID            No
# 1    2014-08-27 15:32:09   28    male         Germany  None            No
# 2    2014-08-27 15:32:19   26       M         Uruguay  None            No
# 3    2014-08-27 15:32:43   28    Male     New Zealand  None            No
# 4    2014-08-27 15:34:23   32    Male  United Kingdom  None            No
# ..                   ...  ...     ...             ...   ...           ...
# 414  2014-08-28 15:54:35   29       F   United States    CA            No
# 415  2014-08-28 15:56:47   34    male   United States    TX            No
# 416  2014-08-28 16:09:35   44    Male  United Kingdom  None            No
# 417  2014-08-28 16:17:09   24  female   United States    NY            No
# 418  2014-08-28 16:31:00   47       F   United States    PA            No
#
#     family_history treatment work_interfere no_employees  ...  \
# 0              Yes       Yes      Sometimes          1-5  ...
# 1              Yes       Yes         Rarely          1-5  ...
# 2               No        No           None       26-100  ...
# 3              Yes       Yes      Sometimes         6-25  ...
# 4              Yes       Yes      Sometimes         6-25  ...
# ..             ...       ...            ...          ...  ...
# 414            Yes       Yes         Rarely      100-500  ...
# 415             No       Yes      Sometimes          1-5  ...
# 416            Yes       Yes      Sometimes     500-1000  ...
# 417            Yes       Yes          Often         6-25  ...
# 418             No        No           None      100-500  ...
#
#                   leave mental_health_consequence phys_health_consequence  \
# 0            Don't know                       Yes                   Maybe
# 1             Very easy                        No                      No
# 2            Don't know                        No                      No
# 3             Very easy                        No                      No
# 4         Somewhat easy                        No                      No
# ..                  ...                       ...                     ...
# 414          Don't know                        No                      No
# 415          Don't know                       Yes                      No
# 416  Somewhat difficult                     Maybe                      No
# 417           Very easy                        No                      No
# 418      Very difficult                       Yes                     Yes
#
#         coworkers supervisor mental_health_interview phys_health_interview  \
# 0              No         No                      No                    No
# 1             Yes        Yes                      No                    No
# 2    Some of them         No                      No                   Yes
# 3             Yes        Yes                     Yes                   Yes
# 4    Some of them        Yes                      No                    No
# ..            ...        ...                     ...                   ...
# 414           Yes        Yes                      No                 Maybe
# 415            No         No                      No                   Yes
# 416  Some of them        Yes                      No                 Maybe
# 417  Some of them        Yes                      No                   Yes
# 418            No         No                      No                    No
#
#     mental_vs_physical obs_consequence  \
# 0                   No             Yes
# 1                  Yes              No
# 2           Don't know              No
# 3                  Yes              No
# 4           Don't know              No
# ..                 ...             ...
# 414         Don't know              No
# 415         Don't know              No
# 416                 No             Yes
# 417                 No             Yes
# 418                 No              No
#
#                                               comments
# 0                                                 None
# 1    fwiw I am a co founder of this company and the...
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 414                                               None
# 415                                               None
# 416                                               None
# 417                                               None
# 418                                               None
#
# [419 rows x 27 columns]

# %%
conn = sqlite3.connect('./test.db')
cur = conn.cursor()
cur.execute('''SELECT name from sqlite_master where type= "table"''').fetchall()
cur.close()

# %%
pd.read_sql('''SELECT name from sqlite_master where type= "table"''', conn)
# Out:
#                                                  name
# 0                             Life Expectancy Data_p1
# 1                             Life Expectancy Data_p2
# 2                             Life Expectancy Data_p3
# 3                   Age-standardized suicide rates_p1
# 4                   Age-standardized suicide rates_p2
# 5                   Age-standardized suicide rates_p3
# 6                              Crude suicide rates_p1
# 7                              Crude suicide rates_p2
# 8                              Crude suicide rates_p3
# 9                                       Facilities_p1
# 10                                      Facilities_p2
# 11                                      Facilities_p3
# 12                                 Human Resources_p1
# 13                                 Human Resources_p2
# 14                                 Human Resources_p3
# 15    mental-and-substance-use-as-share-of-disease_p1
# 16    mental-and-substance-use-as-share-of-disease_p2
# 17    mental-and-substance-use-as-share-of-disease_p3
# 18  prevalence-by-mental-and-substance-use-disorde...
# 19  prevalence-by-mental-and-substance-use-disorde...
# 20  prevalence-by-mental-and-substance-use-disorde...
# 21       prevalence-of-depression-males-vs-females_p1
# 22       prevalence-of-depression-males-vs-females_p2
# 23       prevalence-of-depression-males-vs-females_p3
# 24                           share-with-depression_p1
# 25                           share-with-depression_p2
# 26                           share-with-depression_p3
# 27       share-with-mental-and-substance-disorders_p1
# 28       share-with-mental-and-substance-disorders_p2
# 29       share-with-mental-and-substance-disorders_p3
# 30  share-with-mental-or-substance-disorders-by-se...
# 31  share-with-mental-or-substance-disorders-by-se...
# 32  share-with-mental-or-substance-disorders-by-se...
# 33                                          survey_p1
# 34                                          survey_p2
# 35                                          survey_p3
# 36                                            2015_p1
# 37                                            2015_p2
# 38                                            2015_p3
# 39                                            2016_p1
# 40                                            2016_p2
# 41                                            2016_p3
# 42                                            2017_p1
# 43                                            2017_p2
# 44                                            2017_p3
# 45                                            2018_p1
# 46                                            2018_p2
# 47                                            2018_p3
# 48                                            2019_p1
# 49                                            2019_p2
# 50                                            2019_p3
# 51                                            2020_p1
# 52                                            2020_p2
# 53                                            2020_p3
# 54                                            2021_p1
# 55                                            2021_p2
# 56                                            2021_p3

# %%
for i in files:
#     print(os.path.splitext(i))
#     print（i）
    x = i.split('\\')[-1]
    x = x.split('.')[0]
    print(x)
# Out:
# Life Expectancy Data
# Age-standardized suicide rates
# Crude suicide rates
# Facilities
# Human Resources
# mental-and-substance-use-as-share-of-disease
# prevalence-by-mental-and-substance-use-disorder
# prevalence-of-depression-males-vs-females
# share-with-depression
# share-with-mental-and-substance-disorders
# share-with-mental-or-substance-disorders-by-sex
# survey
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021

# %%
for i in files:
    x = i.split('\\')[-1]
#     x = x.split('.')[0]
    print(x)
# Out:
# Life Expectancy Data.csv
# Age-standardized suicide rates.csv
# Crude suicide rates.csv
# Facilities.csv
# Human Resources.csv
# mental-and-substance-use-as-share-of-disease.csv
# prevalence-by-mental-and-substance-use-disorder.csv
# prevalence-of-depression-males-vs-females.csv
# share-with-depression.csv
# share-with-mental-and-substance-disorders.csv
# share-with-mental-or-substance-disorders-by-sex.csv
# survey.csv
# 2015.csv
# 2016.csv
# 2017.csv
# 2018.csv
# 2019.csv
# 2020.csv
# 2021.csv

# %%
namenode = pd.DataFrame(columns = ['id', 'location', 'name', 'type'])
index = 0
id_list = []
location_list = []
name_list = []
type_list = []
for i in files:
    
    
    namenode[index]['id'] = index
    index = index + 1
    namenode[index]['location'] = i
    namenode[index]['name'] = i.split('\\')[-1]
    namenode[index]['type'] = 'FILE'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [102], in <cell line: 3>()
#       2 index = 0
#       3 for i in files:
# ----> 4     namenode[index]['id'] = index
#       5     index = index + 1
#       6     namenode[index]['location'] = i
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 0

# %%
namenode[0][0] = 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [110], in <cell line: 1>()
# ----> 1 namenode[0][0] = 1
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 0

# %%
namenode
# Out:
# Empty DataFrame
# Columns: [id, location, name, type]
# Index: []
