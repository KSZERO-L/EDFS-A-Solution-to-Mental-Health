# %%
import sqlite3
from sqlite3 import Error
import os
import pandas as pd
import numpy as np
import re

# %%
root_path = './'

# %%
root_path = './'
files = []
for root, _, file in os.walk(root_path):
    for f in file:
        if (os.path.splitext(f)[1] == ".csv"):
            file_path = os.path.join(root, f)
            activity = os.path.split(root)[-1]
            files.append(file_path)

# %%
for root, _, file in os.walk(root_path):
    for f in file:
        if (os.path.splitext(f)[1] == ".csv"):
            print(f)
# Out:
# Age-standardized suicide rates_p1.csv
# Age-standardized suicide rates_p2.csv
# Age-standardized suicide rates_p3.csv
# share-with-mental-and-substance-disorders_p2.csv
# share-with-mental-and-substance-disorders_p3.csv
# share-with-mental-and-substance-disorders_p1.csv
# prevalence-by-mental-and-substance-use-disorder_p2.csv
# share-with-mental-or-substance-disorders-by-sex_p1.csv
# 2018_p1.csv
# prevalence-by-mental-and-substance-use-disorder_p3.csv
# prevalence-by-mental-and-substance-use-disorder_p1.csv
# 2018_p3.csv
# share-with-mental-or-substance-disorders-by-sex_p2.csv
# share-with-mental-or-substance-disorders-by-sex_p3.csv
# 2018_p2.csv
# 2020_p2.csv
# 2016_p3.csv
# survey_p2.csv
# survey_p3.csv
# 2016_p2.csv
# 2020_p3.csv
# 2020_p1.csv
# survey_p1.csv
# 2016_p1.csv
# prevalence-of-depression-males-vs-females_p2.csv
# Human Resources_p3.csv
# mental-and-substance-use-as-share-of-disease_p1.csv
# Human Resources_p2.csv
# prevalence-of-depression-males-vs-females_p3.csv
# prevalence-of-depression-males-vs-females_p1.csv
# mental-and-substance-use-as-share-of-disease_p2.csv
# mental-and-substance-use-as-share-of-disease_p3.csv
# Human Resources_p1.csv
# 2015_p2.csv
# 2019_p2.csv
# 2019_p3.csv
# Crude suicide rates_p1.csv
# 2015_p3.csv
# 2015_p1.csv
# Crude suicide rates_p3.csv
# 2019_p1.csv
# Crude suicide rates_p2.csv
# Life Expectancy Data_p1.csv
# share-with-depression_p3.csv
# Facilities_p2.csv
# 2017_p1.csv
# 2021_p1.csv
# Facilities_p3.csv
# share-with-depression_p2.csv
# Life Expectancy Data_p2.csv
# Facilities_p1.csv
# 2021_p3.csv
# 2017_p2.csv
# 2017_p3.csv
# 2021_p2.csv
# share-with-depression_p1.csv
# Life Expectancy Data_p3.csv
# prevalence-by-mental-and-substance-use-disorder.csv
# share-with-mental-and-substance-disorders.csv
# prevalence-of-depression-males-vs-females.csv
# mental-and-substance-use-as-share-of-disease.csv
# share-with-depression.csv
# share-with-mental-or-substance-disorders-by-sex.csv
# survey.csv
# Crude suicide rates.csv
# Facilities.csv
# Human Resources.csv
# Age-standardized suicide rates.csv
# 2020.csv
# 2021.csv
# 2019.csv
# 2018.csv
# 2015.csv
# 2016.csv
# 2017.csv
# Life Expectancy Data.csv

# %%
files
# Out:
# ['./Age-standardized suicide rates_p1.csv',
#  './Age-standardized suicide rates_p2.csv',
#  './Age-standardized suicide rates_p3.csv',
#  './share-with-mental-and-substance-disorders_p2.csv',
#  './share-with-mental-and-substance-disorders_p3.csv',
#  './share-with-mental-and-substance-disorders_p1.csv',
#  './prevalence-by-mental-and-substance-use-disorder_p2.csv',
#  './share-with-mental-or-substance-disorders-by-sex_p1.csv',
#  './2018_p1.csv',
#  './prevalence-by-mental-and-substance-use-disorder_p3.csv',
#  './prevalence-by-mental-and-substance-use-disorder_p1.csv',
#  './2018_p3.csv',
#  './share-with-mental-or-substance-disorders-by-sex_p2.csv',
#  './share-with-mental-or-substance-disorders-by-sex_p3.csv',
#  './2018_p2.csv',
#  './2020_p2.csv',
#  './2016_p3.csv',
#  './survey_p2.csv',
#  './survey_p3.csv',
#  './2016_p2.csv',
#  './2020_p3.csv',
#  './2020_p1.csv',
#  './survey_p1.csv',
#  './2016_p1.csv',
#  './prevalence-of-depression-males-vs-females_p2.csv',
#  './Human Resources_p3.csv',
#  './mental-and-substance-use-as-share-of-disease_p1.csv',
#  './Human Resources_p2.csv',
#  './prevalence-of-depression-males-vs-females_p3.csv',
#  './prevalence-of-depression-males-vs-females_p1.csv',
#  './mental-and-substance-use-as-share-of-disease_p2.csv',
#  './mental-and-substance-use-as-share-of-disease_p3.csv',
#  './Human Resources_p1.csv',
#  './2015_p2.csv',
#  './2019_p2.csv',
#  './2019_p3.csv',
#  './Crude suicide rates_p1.csv',
#  './2015_p3.csv',
#  './2015_p1.csv',
#  './Crude suicide rates_p3.csv',
#  './2019_p1.csv',
#  './Crude suicide rates_p2.csv',
#  './Life Expectancy Data_p1.csv',
#  './share-with-depression_p3.csv',
#  './Facilities_p2.csv',
#  './2017_p1.csv',
#  './2021_p1.csv',
#  './Facilities_p3.csv',
#  './share-with-depression_p2.csv',
#  './Life Expectancy Data_p2.csv',
#  './Facilities_p1.csv',
#  './2021_p3.csv',
#  './2017_p2.csv',
#  './2017_p3.csv',
#  './2021_p2.csv',
#  './share-with-depression_p1.csv',
#  './Life Expectancy Data_p3.csv',
#  './Mental Health Dataset/prevalence-by-mental-and-substance-use-disorder.csv',
#  './Mental Health Dataset/share-with-mental-and-substance-disorders.csv',
#  './Mental Health Dataset/prevalence-of-depression-males-vs-females.csv',
#  './Mental Health Dataset/mental-and-substance-use-as-share-of-disease.csv',
#  './Mental Health Dataset/share-with-depression.csv',
#  './Mental Health Dataset/share-with-mental-or-substance-disorders-by-sex.csv',
#  './Mental Health in Tech Survey/survey.csv',
#  './Mental Health and Suicide Rates/Crude suicide rates.csv',
#  './Mental Health and Suicide Rates/Facilities.csv',
#  './Mental Health and Suicide Rates/Human Resources.csv',
#  './Mental Health and Suicide Rates/Age-standardized suicide rates.csv',
#  './World Happiness Report 2015-2021/2020.csv',
#  './World Happiness Report 2015-2021/2021.csv',
#  './World Happiness Report 2015-2021/2019.csv',
#  './World Happiness Report 2015-2021/2018.csv',
#  './World Happiness Report 2015-2021/2015.csv',
#  './World Happiness Report 2015-2021/2016.csv',
#  './World Happiness Report 2015-2021/2017.csv',
#  './Life Expectancy (WHO)/Life Expectancy Data.csv']

# %%
for i in files:
    data_test = pd.read_csv(i)

# %%
Life_Expectancy_Data = pd.read_csv(files[0])
Mental_Health_Suicide_Rates_Age_standardized_suicide_rates = pd.read_csv(files[1])
Mental_Health_Suicide_Rates_Crude_suicide_rates = pd.read_csv(files[2])
Mental_Health_Suicide_Rates_Facilities = pd.read_csv(files[3])
Mental_Health_Suicide_Rates_Human_Resources = pd.read_csv(files[4])
Mental_Health_Dataset_mental_and_substance_use_as_share_of_disease = pd.read_csv(files[5])
Mental_Health_Dataset_prevalence_by_mental_and_substance_use_disorder = pd.read_csv(files[6])
Mental_Health_Dataset_prevalence_of_depression_males_vs_females = pd.read_csv(files[7])
Mental_Health_Dataset_share_with_depression = pd.read_csv(files[8])
Mental_Health_Dataset_share_with_mental_and_substance_disorders = pd.read_csv(files[9])
Mental_Health_Dataset_share_with_mental_or_substance_disorders_by_sex = pd.read_csv(files[10])
Mental_Health_Tech_Survey_survey = pd.read_csv(files[11])
World_Happiness_Report_2015_2021_2015 = pd.read_csv(files[12])
World_Happiness_Report_2015_2021_2016 = pd.read_csv(files[13])
World_Happiness_Report_2015_2021_2017 = pd.read_csv(files[14])
World_Happiness_Report_2015_2021_2018 = pd.read_csv(files[15])
World_Happiness_Report_2015_2021_2019 = pd.read_csv(files[16])
World_Happiness_Report_2015_2021_2020 = pd.read_csv(files[17])
World_Happiness_Report_2015_2021_2021 = pd.read_csv(files[18])

# %%
World_Happiness_Report_2015_2021_2021
# Out:
#      Unnamed: 0            Timestamp  Age  Gender         Country state  \
# 0           838  2014-08-28 16:42:49   43       m  United Kingdom   NaN
# 1           839  2014-08-28 16:52:23   36       M   United States    PA
# 2           840  2014-08-28 16:52:34   43    male   United States    GA
# 3           841  2014-08-28 16:52:34   36    male  United Kingdom   NaN
# 4           842  2014-08-28 16:54:49   31  Female   United States    NY
# ..          ...                  ...  ...     ...             ...   ...
# 416        1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN
# 417        1255  2015-09-26 01:07:35   32    Male   United States    IL
# 418        1256  2015-11-07 12:36:58   34    male   United States    CA
# 419        1257  2015-11-30 21:25:06   46       f   United States    NC
# 420        1258  2016-02-01 23:04:31   25    Male   United States    IL
#
#     self_employed family_history treatment work_interfere  ...  \
# 0              No            Yes        No            NaN  ...
# 1              No             No        No         Rarely  ...
# 2              No             No       Yes      Sometimes  ...
# 3             Yes             No        No      Sometimes  ...
# 4              No            Yes       Yes      Sometimes  ...
# ..            ...            ...       ...            ...  ...
# 416            No             No       Yes            NaN  ...
# 417            No            Yes       Yes          Often  ...
# 418            No            Yes       Yes      Sometimes  ...
# 419            No             No        No            NaN  ...
# 420            No            Yes       Yes      Sometimes  ...
#
#                   leave mental_health_consequence phys_health_consequence  \
# 0             Very easy                     Maybe                      No
# 1    Somewhat difficult                        No                      No
# 2        Very difficult                     Maybe                      No
# 3    Somewhat difficult                        No                      No
# 4    Somewhat difficult                        No                      No
# ..                  ...                       ...                     ...
# 416       Somewhat easy                        No                      No
# 417  Somewhat difficult                        No                      No
# 418  Somewhat difficult                       Yes                     Yes
# 419          Don't know                       Yes                      No
# 420          Don't know                     Maybe                      No
#
#         coworkers    supervisor mental_health_interview phys_health_interview  \
# 0    Some of them           Yes                      No                 Maybe
# 1    Some of them           Yes                      No                    No
# 2    Some of them           Yes                      No                    No
# 3             Yes           Yes                      No                 Maybe
# 4             Yes           Yes                   Maybe                 Maybe
# ..            ...           ...                     ...                   ...
# 416  Some of them  Some of them                      No                    No
# 417  Some of them           Yes                      No                    No
# 418            No            No                      No                    No
# 419            No            No                      No                    No
# 420  Some of them            No                      No                    No
#
#     mental_vs_physical obs_consequence  \
# 0           Don't know              No
# 1                   No              No
# 2           Don't know              No
# 3           Don't know             Yes
# 4           Don't know              No
# ..                 ...             ...
# 416         Don't know              No
# 417                Yes              No
# 418                 No              No
# 419                 No              No
# 420         Don't know              No
#
#                                               comments
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    I have been incredibly public about my own str...
# ..                                                 ...
# 416                                                NaN
# 417                                                NaN
# 418                                                NaN
# 419                                                NaN
# 420                                                NaN
#
# [421 rows x 28 columns]

# %%
# def create_connection(db_file):
#     """ create a database connection to a SQLite database """
#     conn = None
#     try:
#         conn = sqlite3.connect(db_file)
#         print(sqlite3.version)
#     except Error as e:
#         print(e)
#     finally:
#         if conn:
#             conn.close()


# if __name__ == '__main__':
#      create_connection(r"./pythonsqlite.db")

# %%
# cur = conn.cursor()
# cur.execute('''SELECT * FROM Life_Expectancy_Data''').fetchall()

# %%
# pd.read_sql('''SELECT * FROM Life_Expectancy_Data''', conn)

# %%
# pd.read_sql('''SELECT * FROM Life_Expectancy_Data PARTITION BY HASH(Country) PARTITIONS 4''', conn)

# %%
# len(Life_Expectancy_Data)//3

# %%
# Life_Expectancy_Data[:len(Life_Expectancy_Data)//3]

# %%
# Life_Expectancy_Data[len(Life_Expectancy_Data)//3:len(Life_Expectancy_Data)//3*2]

# %%
# Life_Expectancy_Data[len(Life_Expectancy_Data)//3*2:len(Life_Expectancy_Data)]

# %%
def create_connection(db_file):
    """ create a database connection to a SQLite database """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
    finally:
        if conn:
            conn.close()


if __name__ == '__main__':
    create_connection(r"./test.db")
# Out:
# 2.6.0

# %%
# conn = sqlite3.connect('./test.db')
# cur = conn.cursor()
# Life_Expectancy_Data.to_sql('Life_Expectancy_Data', conn, if_exists='append', index = False)
# # conn.commit()
# cur.close()

# %%
files
# Out:
# ['./Age-standardized suicide rates_p1.csv',
#  './Age-standardized suicide rates_p2.csv',
#  './Age-standardized suicide rates_p3.csv',
#  './share-with-mental-and-substance-disorders_p2.csv',
#  './share-with-mental-and-substance-disorders_p3.csv',
#  './share-with-mental-and-substance-disorders_p1.csv',
#  './prevalence-by-mental-and-substance-use-disorder_p2.csv',
#  './share-with-mental-or-substance-disorders-by-sex_p1.csv',
#  './2018_p1.csv',
#  './prevalence-by-mental-and-substance-use-disorder_p3.csv',
#  './prevalence-by-mental-and-substance-use-disorder_p1.csv',
#  './2018_p3.csv',
#  './share-with-mental-or-substance-disorders-by-sex_p2.csv',
#  './share-with-mental-or-substance-disorders-by-sex_p3.csv',
#  './2018_p2.csv',
#  './2020_p2.csv',
#  './2016_p3.csv',
#  './survey_p2.csv',
#  './survey_p3.csv',
#  './2016_p2.csv',
#  './2020_p3.csv',
#  './2020_p1.csv',
#  './survey_p1.csv',
#  './2016_p1.csv',
#  './prevalence-of-depression-males-vs-females_p2.csv',
#  './Human Resources_p3.csv',
#  './mental-and-substance-use-as-share-of-disease_p1.csv',
#  './Human Resources_p2.csv',
#  './prevalence-of-depression-males-vs-females_p3.csv',
#  './prevalence-of-depression-males-vs-females_p1.csv',
#  './mental-and-substance-use-as-share-of-disease_p2.csv',
#  './mental-and-substance-use-as-share-of-disease_p3.csv',
#  './Human Resources_p1.csv',
#  './2015_p2.csv',
#  './2019_p2.csv',
#  './2019_p3.csv',
#  './Crude suicide rates_p1.csv',
#  './2015_p3.csv',
#  './2015_p1.csv',
#  './Crude suicide rates_p3.csv',
#  './2019_p1.csv',
#  './Crude suicide rates_p2.csv',
#  './Life Expectancy Data_p1.csv',
#  './share-with-depression_p3.csv',
#  './Facilities_p2.csv',
#  './2017_p1.csv',
#  './2021_p1.csv',
#  './Facilities_p3.csv',
#  './share-with-depression_p2.csv',
#  './Life Expectancy Data_p2.csv',
#  './Facilities_p1.csv',
#  './2021_p3.csv',
#  './2017_p2.csv',
#  './2017_p3.csv',
#  './2021_p2.csv',
#  './share-with-depression_p1.csv',
#  './Life Expectancy Data_p3.csv',
#  './Mental Health Dataset/prevalence-by-mental-and-substance-use-disorder.csv',
#  './Mental Health Dataset/share-with-mental-and-substance-disorders.csv',
#  './Mental Health Dataset/prevalence-of-depression-males-vs-females.csv',
#  './Mental Health Dataset/mental-and-substance-use-as-share-of-disease.csv',
#  './Mental Health Dataset/share-with-depression.csv',
#  './Mental Health Dataset/share-with-mental-or-substance-disorders-by-sex.csv',
#  './Mental Health in Tech Survey/survey.csv',
#  './Mental Health and Suicide Rates/Crude suicide rates.csv',
#  './Mental Health and Suicide Rates/Facilities.csv',
#  './Mental Health and Suicide Rates/Human Resources.csv',
#  './Mental Health and Suicide Rates/Age-standardized suicide rates.csv',
#  './World Happiness Report 2015-2021/2020.csv',
#  './World Happiness Report 2015-2021/2021.csv',
#  './World Happiness Report 2015-2021/2019.csv',
#  './World Happiness Report 2015-2021/2018.csv',
#  './World Happiness Report 2015-2021/2015.csv',
#  './World Happiness Report 2015-2021/2016.csv',
#  './World Happiness Report 2015-2021/2017.csv',
#  './Life Expectancy (WHO)/Life Expectancy Data.csv']

# %%
conn = sqlite3.connect('./test.db')
cur = conn.cursor()
for i in files:
    casedf = pd.read_csv(i)
    #equal length partition
    casedf_p1 = casedf[:len(casedf)//3]
    casedf_p2 = casedf[len(casedf)//3:len(casedf)//3*2]
    casedf_p3 = casedf[len(casedf)//3*2:len(casedf)]
    
    file_name = i.split('\\')[-1]
    file_name = file_name.split('.')[0]
    file_name_p1 = file_name + '_p1'
    file_name_p2 = file_name + '_p2'
    file_name_p3 = file_name + '_p3'
    
#     casedf_p1.to_csv(file_name_p1 + '.csv')
#     casedf_p2.to_csv(file_name_p2 + '.csv')
#     casedf_p3.to_csv(file_name_p3 + '.csv')
    
    casedf_p1.to_sql(file_name_p1, conn, if_exists='append', index = False)
    cur.close()
    casedf_p2.to_sql(file_name_p2, conn, if_exists='append', index = False)
    cur.close()
    casedf_p3.to_sql(file_name_p3, conn, if_exists='append', index = False)
    cur.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [40], in <cell line: 3>()
#      14     file_name_p3 = file_name + '_p3'
#      16 #     casedf_p1.to_csv(file_name_p1 + '.csv')
#      17 #     casedf_p2.to_csv(file_name_p2 + '.csv')
#      18 #     casedf_p3.to_csv(file_name_p3 + '.csv')
# ---> 20     casedf_p1.to_sql(file_name_p1, conn, if_exists='append', index = False)
#      21     cur.close()
#      22     casedf_p2.to_sql(file_name_p2, conn, if_exists='append', index = False)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:697, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     692 elif not isinstance(frame, DataFrame):
#     693     raise NotImplementedError(
#     694         "'frame' argument should be either a Series or a DataFrame"
#     695     )
# --> 697 return pandas_sql.to_sql(
#     698     frame,
#     699     name,
#     700     if_exists=if_exists,
#     701     index=index,
#     702     index_label=index_label,
#     703     schema=schema,
#     704     chunksize=chunksize,
#     705     dtype=dtype,
#     706     method=method,
#     707     engine=engine,
#     708     **engine_kwargs,
#     709 )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:2190, in SQLiteDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, **kwargs)
#    2180 table = SQLiteTable(
#    2181     name,
#    2182     self,
#    (...)
#    2187     dtype=dtype,
#    2188 )
#    2189 table.create()
# -> 2190 return table.insert(chunksize, method)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:950, in SQLTable.insert(self, chunksize, method)
#     947     break
#     949 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# --> 950 num_inserted = exec_insert(conn, keys, chunk_iter)
#     951 if num_inserted is None:
#     952     total_inserted = None
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:1896, in SQLiteTable._execute_insert(self, conn, keys, data_iter)
#    1894 def _execute_insert(self, conn, keys, data_iter) -> int:
#    1895     data_list = list(data_iter)
# -> 1896     conn.executemany(self.insert_statement(num_rows=1), data_list)
#    1897     return conn.rowcount
#
# OperationalError: table _p1 has no column named Entity

# %%
pd.read_sql('''SELECT * FROM survey_p2''', conn)

# %%
conn = sqlite3.connect('./test.db')
cur = conn.cursor()
cur.execute('''SELECT name from sqlite_master where type= "table"''').fetchall()
cur.close()

# %%
pd.read_sql('''SELECT name from sqlite_master where type= "table"''', conn)

# %%
for i in files:
#     print(os.path.splitext(i))
#     print（i）
    x = i.split('\\')[-1]
    x = x.split('.')[0]
    print(x)
